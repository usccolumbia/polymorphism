# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\moons\\OneDrive\\Documents\\paper_1_final\\polymorphism\\codes'

# %%
import pandas as pd
df=pd.read_csv(r'../dataset/dataset_polymorphs_icsd.csv')
print(df.shape,df.columns)

from pymatgen.core import Composition
df['elements'] = df['reduced_formula'].apply(lambda x: [str(el) for el in Composition(x).elements])
# Out:
# (28785, 18) Index(['index', 'filename', 'reduced_formula', 'full_formula', 'num_sites',
#        'status', 'r_val', 'quality_tag', 'temperature', 'pressure', 'sgr',
#        'is_polymorph', 'polymorph_count', 'sg_number', 'refined_sg_number',
#        'refined_sg_symbol', 'is_organic', 'prototype'],
#       dtype='object')

# %%
df['reduced_formula'].value_counts()
# Out:
# reduced_formula
# SiO2                      196
# ZnS                       195
# CdI2                      147
# MgAl2O4                    97
# Mg(FeO2)2                  83
#                          ...
# Cu(RhS2)2                   1
# Cu1.7Ge0.3                  1
# Cu107.968N72Cl180O14.4      1
# Cu12PdN4                    1
# BaSn                        1
# Name: count, Length: 16334, dtype: int64

# %% [markdown]
# ### Composition and Symmetry Distribution (ICSD)

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count element frequency across all unique formulas (irrespective of prototype)
all_elements = []

for formula in df['reduced_formula'].unique():
    formula_rows = df[df['reduced_formula'] == formula]
    # Get elements from first row of this formula
    elements_list = formula_rows['elements'].iloc[0]
    unique_elements = set(elements_list)
    all_elements.extend(unique_elements)

# Count element frequencies
element_counts = Counter(all_elements)
element_freq = element_counts.most_common(20)  # Top 20 elements only

# Prepare data for plotting
elements = [x[0] for x in element_freq]
counts = [x[1] for x in element_freq]

# Create bar chart
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_ylim(0, 7500)
bars = ax.bar(elements, counts, color='white', edgecolor='purple', linewidth=0.5)
ax.set_xlabel('Element', fontsize=20)
ax.set_ylabel('Presence in formula', fontsize=20)
ax.set_title('Element Frequency Across All Formulas', fontsize=20)
ax.tick_params(axis='both', labelsize=20)
ax.grid(axis='y', alpha=0.3, linestyle='--')

# Add count labels on top of bars
for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{count}',
            ha='center', va='bottom', fontsize=15,rotation=45)

plt.xticks(rotation=45)
plt.tight_layout()
# plt.savefig('mproject_icsd_elements_bar_polymorphs.png', dpi=300, bbox_inches='tight')
plt.show()

print(f'Total unique formulas: {df["reduced_formula"].nunique()}')
print(f'Total unique elements: {len(element_counts)}')
print(f'\nTop 10 most frequent elements:')
for elem, count in element_freq[:10]:
    print(f'{elem}: {count}')
# Out:
# Total unique formulas: 16334
# Total unique elements: 93
#
# Top 10 most frequent elements:
# O: 6845
# Fe: 1600
# Si: 1578
# Cu: 1431
# S: 1421
# Mn: 1337
# Al: 1172
# H: 1123
# P: 1108
# Ni: 1087

# %%
df_hub=df
group = [
 'Binary','Fluorite/Rutile','Perovskite','Quaternary','Rocksalt/Zincblende/CsCl','Ternary','Other']
for i in group:
    df_x=df_hub[df_hub['prototype']==i]
    formulas=df_x['reduced_formula'].unique().tolist()
    print(i,len(formulas))
    df_x=df[df_hub['prototype']==i]
    formulas=df_x['reduced_formula'].unique().tolist()
    print(i,len(formulas))
    print('\n')
# Out:
# Binary 2316
# Binary 2316
#
#
# Fluorite/Rutile 1034
# Fluorite/Rutile 1034
#
#
# Perovskite 410
# Perovskite 410
#
#
# Quaternary 3780
# Quaternary 3780
#
#
# Rocksalt/Zincblende/CsCl 1053
# Rocksalt/Zincblende/CsCl 1053
#
#
# Ternary 6486
# Ternary 6486
#
#
# Other 1291
# Other 1291

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count space group frequency across all structures (all mp_id)
sg_counts = Counter(df['sg_number'])
sg_freq = sg_counts.most_common(20)  # Top 20 space groups

# Prepare data for plotting
space_groups = [str(int(x[0])) for x in sg_freq]
counts = [x[1] for x in sg_freq]

# Create bar chart
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.bar(space_groups, counts, color='white', edgecolor='purple', linewidth=0.5)
ax.set_xlabel('Space Group Number', fontsize=20)
ax.set_ylabel('Presence in structures', fontsize=20)
ax.set_title('Space Group Frequency Across All Structures', fontsize=20)
ax.tick_params(axis='both', labelsize=20)
ax.grid(axis='y', alpha=0.3, linestyle='--')

# Add count labels on top of bars
for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{count}',
            ha='center', va='bottom', fontsize=15)

plt.xticks(rotation=45)
plt.tight_layout()
# plt.savefig('mproject_icsd_sg_num_counts.png', dpi=300, bbox_inches='tight')
plt.show()

print(f'Total structures: {len(df)}')
print(f'Total unique space groups: {len(sg_counts)}')
print(f'\nTop 10 most frequent space groups:')
for sg, count in sg_freq[:10]:
    print(f'SG {sg}: {count}')
# Out:
# Total structures: 28785
# Total unique space groups: 8769
#
# Top 10 most frequent space groups:
# SG 62.0: 1993
# SG 225.0: 1850
# SG 227.0: 1637
# SG 139.0: 1363
# SG 194.0: 1147
# SG 14.0: 1069
# SG 221.0: 922
# SG 12.0: 648
# SG 15.0: 637
# SG 2.0: 587

# %%
import matplotlib.pyplot as plt

# Count formulas and get top 20 with most polymorphs
formula_counts = df['reduced_formula'].value_counts()
top_formulas = formula_counts.head(18)

# Prepare data for plotting
formulas = top_formulas.index.tolist()
counts = top_formulas.values.tolist()

# Convert formulas to subscript notation for display
def format_formula(formula):
    """Convert formula to subscript notation (e.g., H2O -> H₂O)"""
    import re
    # Replace digits with subscript unicode
    subscript_map = str.maketrans('0123456789', '₀₁₂₃₄₅₆₇₈₉')
    return formula.translate(subscript_map)

formulas_display = [format_formula(f) for f in formulas]

# Create bar chart
sizes=20-1
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.bar(range(len(formulas)), counts, color='white', edgecolor='red', linewidth=0.5)
ax.set_xlabel('Reduced Formula', fontsize=sizes)
ax.set_ylabel('Number of polymorphs reported', fontsize=sizes)
ax.set_title('Top 20 Formulas by Polymorph Count', fontsize=sizes)
ax.tick_params(axis='both', labelsize=sizes)
ax.grid(axis='y', alpha=0.3, linestyle='--')

# Set x-ticks with subscript formulas
ax.set_xticks(range(len(formulas)))
ax.set_xticklabels(formulas_display, rotation=45, ha='right')

# Add count labels on top of bars
for bar, count in zip(bars, counts):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{count}',
            ha='center', va='bottom', fontsize=14)

plt.tight_layout()
# plt.savefig('mpro_icsd_top_polymorph.png', dpi=300, bbox_inches='tight')
plt.show()

print(f'Total unique formulas: {len(formula_counts)}')
print(f'\nTop 18 formulas with most polymorphs:')
for formula, count in top_formulas.items():
    print(f'{formula}: {count}')
# Out:
# Total unique formulas: 16334
#
# Top 18 formulas with most polymorphs:
# SiO2: 196
# ZnS: 195
# CdI2: 147
# MgAl2O4: 97
# Mg(FeO2)2: 83
# Al2NiO4: 65
# SiC: 46
# AlPO4: 39
# Al2FeO4: 37
# C: 34
# MgTi2O5: 34
# CuI: 30
# Zn(FeO2)2: 25
# S: 24
# Bi2O3: 24
# CaMg(CO3)2: 22
# Mg2TiO4: 22
# H2O: 21

# %%
import pandas as pd
from itertools import combinations
from collections import Counter

# Step 1: Get unique sg_num values for each reduced_formula
unique_sg_per_formula = df.groupby('reduced_formula')['sg_number'].unique()

# Step 2: Find pairs of sg_num within each formula's unique list
pair_counts = Counter()

# Iterate through each formula's unique sg_num list
for sg_nums in unique_sg_per_formula:
    # Generate all pairs of space group numbers (combinations of 2)
    for pair in combinations(sorted(sg_nums), 2):
        pair_counts[pair] += 1

# Step 3: Identify the top 5 most frequent pairs
top_5_pairs = pair_counts.most_common(5)

# Display the top 5 most frequent pairs
for pair, count in top_5_pairs:
    print(f"The pair {pair} is found together in {count} formulas.")
# Out:
# The pair (221.0, 225.0) is found together in 104 formulas.
# The pair (216.0, 225.0) is found together in 99 formulas.
# The pair (194.0, 225.0) is found together in 89 formulas.
# The pair (14.0, 15.0) is found together in 76 formulas.
# The pair (2.0, 14.0) is found together in 67 formulas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from collections import Counter

# Step 1: Get unique sg_num values for each reduced_formula
unique_sg_per_formula = df.groupby('reduced_formula')['sg_number'].unique()

# Step 2: Find pairs of sg_num within each formula's unique list
pair_counts = Counter()

# Iterate through each formula's unique sg_num list
for sg_nums in unique_sg_per_formula:
    # Generate all pairs of space group numbers (combinations of 2)
    for pair in combinations(sorted(sg_nums), 2):
        pair_counts[pair] += 1

# Step 3: Get the top 5 most frequent pairs
top_5_pairs = pair_counts.most_common(5)

# Step 4: Prepare data for the bar plot
pairs, counts = zip(*top_5_pairs)

# Step 5: Create bar plot
plt.figure(figsize=(5, 5))
sns.barplot(x=[f'{int(pair[0])} - {int(pair[1])}' for pair in pairs], y=counts, facecolor='white', edgecolor='purple')

# Add labels and title
plt.xlabel('Space Group Pairs', fontsize=18)
plt.ylabel('Number of unique formulas', fontsize=18)
# plt.title('Top 5 Most Frequent Space Group Pairs', fontsize=18)
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)


# Save the plot
plt.tight_layout()
# plt.savefig('mpro_icsd_top_5_sg_pairs.png', dpi=200)

# Show the plot
plt.show()

# %% [markdown]
# Save the pairs for plotting

# %% [markdown]
# ## The codes below will save the space group pairs in json for Figure 3

# %%
import numpy as np
import random
def report(a1,a2):
    pair=[]
    for i1,i2 in unique_sg_per_formula.items():
        if len(i2)>1:
            if a1 in i2 and a2 in i2:
                pair.append(i1)
    they=[]
    aas=[a1,a2]
    dic={}
    for ke in aas:
        for i in pair:
            df2=df[(df['reduced_formula']==i) & (df['sg_number']==ke)]['filename'].tolist()[0]
            they.append(df2)
        # they=['cifs/'+i for i in they]
        df4=pd.read_csv(r'../dataset/dataset_polymorphs_icsd.csv')
        # import pandas as pd
        # df=pd.read_csv('dataset/dataset_polymorphs_deduped.csv')

        df5=df4[df4['filename'].isin(they)]
        dic[str(ke)]=df5['filename'].tolist()
        print(df5['prototype'].value_counts(),df5['sg_number'].value_counts())
        print(df5['filename'].tolist()[:5],df5['sg_number'].tolist()[:5],df5['prototype'].tolist()[:5])
    return dic

# %%
import json

vals = list(pair_counts.items())
vals.sort(key=lambda k: k[1], reverse=True)

for i in range(15):
    a1, a2 = vals[i][0][0], vals[i][0][1]
    # print(vals[i][0], a1, a2) # a1,a2 space group pair names
    res = report(a1, a2)

    filename = f"sg_icsd_pair_{int(a1)}-{int(a2)}.json"
    with open(filename, "w") as f:
        json.dump(res, f, indent=4)

    print(f"Saved result to {filename}")
    print('**' * 20, '\n')
# Out:
# prototype
# Rocksalt/Zincblende/CsCl    57
# Ternary                     35
# Spinel                       5
# Quaternary                   2
# Binary                       1
# Name: count, dtype: int64 sg_number
# 216.0    100
# Name: count, dtype: int64
# ['157431.cif', '162753.cif', '164973.cif', '108238.cif', '163467.cif'] [216.0, 216.0, 216.0, 216.0, 216.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl']
# prototype
# Rocksalt/Zincblende/CsCl    111
# Ternary                      69
# Spinel                       11
# Quaternary                    4
# Binary                        3
# Other                         1
# Name: count, dtype: int64 sg_number
# 216.0    100
# 225.0     99
# Name: count, dtype: int64
# ['157431.cif', '162753.cif', '163381.cif', '164973.cif', '182362.cif'] [216.0, 216.0, 225.0, 216.0, 225.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl']
# Saved result to sg_icsd_pair_216-225.json
# ****************************************
#
# prototype
# Rocksalt/Zincblende/CsCl    82
# Binary                      19
# Perovskite                   2
# Ternary                      2
# Other                        1
# Name: count, dtype: int64 sg_number
# 221.0    106
# Name: count, dtype: int64
# ['163382.cif', '648602.cif', '181095.cif', '162605.cif', '161582.cif'] [221.0, 221.0, 221.0, 221.0, 221.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl']
# prototype
# Rocksalt/Zincblende/CsCl    161
# Binary                       43
# Other                         3
# Ternary                       3
# Perovskite                    2
# Name: count, dtype: int64 sg_number
# 225.0    106
# 221.0    106
# Name: count, dtype: int64
# ['163381.cif', '163382.cif', '153711.cif', '648602.cif', '159874.cif'] [225.0, 221.0, 225.0, 221.0, 225.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl']
# Saved result to sg_icsd_pair_221-225.json
# ****************************************
#
# prototype
# Other                       50
# Rocksalt/Zincblende/CsCl    23
# Fluorite/Rutile             14
# Binary                       6
# Ternary                      2
# Name: count, dtype: int64 sg_number
# 194.0    95
# Name: count, dtype: int64
# ['181457.cif', '167204.cif', '52459.cif', '28339.cif', '55118.cif'] [194.0, 194.0, 194.0, 194.0, 194.0] ['Rocksalt/Zincblende/CsCl', 'Other', 'Other', 'Other', 'Fluorite/Rutile']
# prototype
# Other                       99
# Rocksalt/Zincblende/CsCl    46
# Binary                      21
# Fluorite/Rutile             18
# Ternary                      3
# Name: count, dtype: int64 sg_number
# 194.0    95
# 225.0    92
# Name: count, dtype: int64
# ['101007.cif', '181457.cif', '167204.cif', '181070.cif', '52458.cif'] [225.0, 194.0, 194.0, 225.0, 225.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Other', 'Other', 'Other']
# Saved result to sg_icsd_pair_194-225.json
# ****************************************
#
# prototype
# Ternary                     48
# Rocksalt/Zincblende/CsCl    11
# Other                        3
# Fluorite/Rutile              2
# Binary                       2
# Spinel                       1
# Quaternary                   1
# Perovskite                   1
# Name: count, dtype: int64 sg_number
# 186.0    69
# Name: count, dtype: int64
# ['31170.cif', '161842.cif', '636533.cif', '30101.cif', '162873.cif'] [186.0, 186.0, 186.0, 186.0, 186.0] ['Other', 'Rocksalt/Zincblende/CsCl', 'Other', 'Other', 'Rocksalt/Zincblende/CsCl']
# prototype
# Ternary                     77
# Rocksalt/Zincblende/CsCl    22
# Other                        7
# Binary                       6
# Fluorite/Rutile              3
# Spinel                       2
# Quaternary                   2
# Perovskite                   1
# Name: count, dtype: int64 sg_number
# 186.0    69
# 194.0    51
# Name: count, dtype: int64
# ['27422.cif', '31170.cif', '161842.cif', '181457.cif', '167204.cif'] [194.0, 186.0, 186.0, 194.0, 194.0] ['Other', 'Other', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Other']
# Saved result to sg_icsd_pair_186-194.json
# ****************************************
#
# prototype
# Binary                      2
# Ternary                     2
# Perovskite                  1
# Rocksalt/Zincblende/CsCl    1
# Name: count, dtype: int64 sg_number
# 14.0    6
# Name: count, dtype: int64
# ['202543.cif', '16828.cif', '182023.cif', '24694.cif', '171458.cif'] [14.0, 14.0, 14.0, 14.0, 14.0] ['Binary', 'Binary', 'Perovskite', 'Rocksalt/Zincblende/CsCl', 'Ternary']
# prototype
# Binary                      4
# Ternary                     4
# Rocksalt/Zincblende/CsCl    2
# Perovskite                  1
# Name: count, dtype: int64 sg_number
# 14.0    6
# 15.0    5
# Name: count, dtype: int64
# ['202543.cif', '16828.cif', '38230.cif', '182023.cif', '24694.cif'] [14.0, 14.0, 15.0, 14.0, 14.0] ['Binary', 'Binary', 'Binary', 'Perovskite', 'Rocksalt/Zincblende/CsCl']
# Saved result to sg_icsd_pair_14-15.json
# ****************************************
#
# prototype
# Rocksalt/Zincblende/CsCl    25
# Ternary                     18
# Perovskite                   7
# Fluorite/Rutile              3
# Binary                       2
# Other                        1
# Name: count, dtype: int64 sg_number
# 62.0    56
# Name: count, dtype: int64
# ['151950.cif', '182269.cif', '16768.cif', '246514.cif', '108293.cif'] [62.0, 62.0, 62.0, 62.0, 62.0] ['Perovskite', 'Other', 'Ternary', 'Perovskite', 'Rocksalt/Zincblende/CsCl']
# prototype
# Rocksalt/Zincblende/CsCl    48
# Ternary                     34
# Perovskite                  13
# Fluorite/Rutile              5
# Binary                       4
# Other                        1
# Spinel                       1
# Name: count, dtype: int64 sg_number
# 62.0    56
# 63.0    50
# Name: count, dtype: int64
# ['151950.cif', '158959.cif', '182269.cif', '16768.cif', '2118.cif'] [62.0, 63.0, 62.0, 62.0, 63.0] ['Perovskite', 'Perovskite', 'Other', 'Ternary', 'Ternary']
# Saved result to sg_icsd_pair_62-63.json
# ****************************************
#
# prototype
# Ternary            11
# Quaternary          7
# Fluorite/Rutile     3
# Spinel              1
# Binary              1
# Name: count, dtype: int64 sg_number
# 2.0    23
# Name: count, dtype: int64
# ['1501.cif', '22088.cif', '280955.cif', '421341.cif', '63057.cif'] [2.0, 2.0, 2.0, 2.0, 2.0] ['Fluorite/Rutile', 'Spinel', 'Ternary', 'Ternary', 'Ternary']
# prototype
# Ternary            12
# Quaternary          8
# Fluorite/Rutile     4
# Binary              3
# Spinel              2
# Perovskite          1
# Name: count, dtype: int64 sg_number
# 2.0     23
# 14.0     7
# Name: count, dtype: int64
# ['150.cif', '31823.cif', '1501.cif', '15889.cif', '164147.cif'] [14.0, 14.0, 2.0, 14.0, 14.0] ['Perovskite', 'Binary', 'Fluorite/Rutile', 'Fluorite/Rutile', 'Ternary']
# Saved result to sg_icsd_pair_2-14.json
# ****************************************
#
# prototype
# Fluorite/Rutile             4
# Perovskite                  4
# Rocksalt/Zincblende/CsCl    4
# Quaternary                  4
# Ternary                     4
# Binary                      2
# Other                       2
# Name: count, dtype: int64 sg_number
# 14.0    24
# Name: count, dtype: int64
# ['154035.cif', '150.cif', '157403.cif', '31823.cif', '162003.cif'] [14.0, 14.0, 14.0, 14.0, 14.0] ['Fluorite/Rutile', 'Perovskite', 'Fluorite/Rutile', 'Binary', 'Perovskite']
# prototype
# Perovskite                  11
# Ternary                     11
# Fluorite/Rutile              9
# Rocksalt/Zincblende/CsCl     7
# Quaternary                   6
# Other                        4
# Binary                       3
# Name: count, dtype: int64 sg_number
# 62.0    27
# 14.0    24
# Name: count, dtype: int64
# ['154035.cif', '182577.cif', '150.cif', '157301.cif', '151950.cif'] [14.0, 62.0, 14.0, 62.0, 62.0] ['Fluorite/Rutile', 'Fluorite/Rutile', 'Perovskite', 'Perovskite', 'Perovskite']
# Saved result to sg_icsd_pair_14-62.json
# ****************************************
#
# prototype
# Perovskite                  25
# Rocksalt/Zincblende/CsCl    18
# Ternary                      9
# Binary                       3
# Name: count, dtype: int64 sg_number
# 62.0    55
# Name: count, dtype: int64
# ['240462.cif', '150420.cif', '153709.cif', '153307.cif', '648438.cif'] [62.0, 62.0, 62.0, 62.0, 62.0] ['Perovskite', 'Perovskite', 'Rocksalt/Zincblende/CsCl', 'Perovskite', 'Rocksalt/Zincblende/CsCl']
# prototype
# Perovskite                  53
# Rocksalt/Zincblende/CsCl    37
# Ternary                     17
# Binary                       6
# Name: count, dtype: int64 sg_number
# 221.0    58
# 62.0     55
# Name: count, dtype: int64
# ['240406.cif', '240462.cif', '67749.cif', '150420.cif', '153709.cif'] [221.0, 62.0, 221.0, 62.0, 62.0] ['Perovskite', 'Perovskite', 'Binary', 'Perovskite', 'Rocksalt/Zincblende/CsCl']
# Saved result to sg_icsd_pair_62-221.json
# ****************************************
#
# prototype
# Ternary                     49
# Quaternary                   3
# Rocksalt/Zincblende/CsCl     1
# Name: count, dtype: int64 sg_number
# 129.0    53
# Name: count, dtype: int64
# ['90993.cif', '167712.cif', '85905.cif', '181770.cif', '411678.cif'] [129.0, 129.0, 129.0, 129.0, 129.0] ['Rocksalt/Zincblende/CsCl', 'Ternary', 'Ternary', 'Ternary', 'Ternary']
# prototype
# Ternary                     100
# Quaternary                    6
# Rocksalt/Zincblende/CsCl      2
# Name: count, dtype: int64 sg_number
# 139.0    55
# 129.0    53
# Name: count, dtype: int64
# ['28495.cif', '90993.cif', '167712.cif', '649640.cif', '154852.cif'] [139.0, 129.0, 129.0, 139.0, 139.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Ternary', 'Ternary', 'Ternary']
# Saved result to sg_icsd_pair_129-139.json
# ****************************************
#
# prototype
# Rocksalt/Zincblende/CsCl    14
# Binary                       4
# Perovskite                   3
# Quaternary                   2
# Other                        1
# Name: count, dtype: int64 sg_number
# 123.0    24
# Name: count, dtype: int64
# ['109327.cif', '168904.cif', '54349.cif', '58766.cif', '105688.cif'] [123.0, 123.0, 123.0, 123.0, 123.0] ['Perovskite', 'Perovskite', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Binary']
# prototype
# Rocksalt/Zincblende/CsCl    34
# Binary                       8
# Perovskite                   7
# Quaternary                   4
# Ternary                      3
# Other                        2
# Name: count, dtype: int64 sg_number
# 221.0    34
# 123.0    24
# Name: count, dtype: int64
# ['109327.cif', '153406.cif', '168902.cif', '168904.cif', '168642.cif'] [123.0, 221.0, 221.0, 123.0, 221.0] ['Perovskite', 'Perovskite', 'Perovskite', 'Perovskite', 'Rocksalt/Zincblende/CsCl']
# Saved result to sg_icsd_pair_123-221.json
# ****************************************
#
# prototype
# Rocksalt/Zincblende/CsCl    33
# Ternary                     18
# Other                        2
# Name: count, dtype: int64 sg_number
# 186.0    53
# Name: count, dtype: int64
# ['15477.cif', '24772.cif', '31170.cif', '154486.cif', '15325.cif'] [186.0, 186.0, 186.0, 186.0, 186.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Other', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl']
# prototype
# Rocksalt/Zincblende/CsCl    66
# Ternary                     35
# Other                        2
# Spinel                       1
# Name: count, dtype: int64 sg_number
# 186.0    53
# 216.0    51
# Name: count, dtype: int64
# ['108733.cif', '15477.cif', '157431.cif', '24772.cif', '31170.cif'] [216.0, 186.0, 216.0, 186.0, 186.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Other']
# Saved result to sg_icsd_pair_186-216.json
# ****************************************
#
# prototype
# Ternary                     15
# Rocksalt/Zincblende/CsCl    13
# Binary                      11
# Fluorite/Rutile              7
# Other                        5
# Perovskite                   1
# Quaternary                   1
# Name: count, dtype: int64 sg_number
# 62.0    53
# Name: count, dtype: int64
# ['173963.cif', '153709.cif', '31543.cif', '55137.cif', '108293.cif'] [62.0, 62.0, 62.0, 62.0, 62.0] ['Fluorite/Rutile', 'Rocksalt/Zincblende/CsCl', 'Other', 'Binary', 'Rocksalt/Zincblende/CsCl']
# prototype
# Rocksalt/Zincblende/CsCl    25
# Binary                      22
# Ternary                     22
# Fluorite/Rutile             15
# Other                       11
# Perovskite                   1
# Quaternary                   1
# Name: count, dtype: int64 sg_number
# 62.0     53
# 225.0    44
# Name: count, dtype: int64
# ['105553.cif', '173963.cif', '153709.cif', '153711.cif', '28338.cif'] [225.0, 62.0, 62.0, 225.0, 225.0] ['Fluorite/Rutile', 'Fluorite/Rutile', 'Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Other']
# Saved result to sg_icsd_pair_62-225.json
# ****************************************
#
# prototype
# Fluorite/Rutile             10
# Binary                      10
# Other                        7
# Ternary                      4
# Rocksalt/Zincblende/CsCl     2
# Quaternary                   1
# Name: count, dtype: int64 sg_number
# 139.0    34
# Name: count, dtype: int64
# ['181908.cif', '246446.cif', '155554.cif', '109038.cif', '108539.cif'] [139.0, 139.0, 139.0, 139.0, 139.0] ['Other', 'Other', 'Fluorite/Rutile', 'Other', 'Fluorite/Rutile']
# prototype
# Binary                      19
# Other                       17
# Fluorite/Rutile             15
# Ternary                      7
# Rocksalt/Zincblende/CsCl     7
# Quaternary                   1
# Name: count, dtype: int64 sg_number
# 139.0    34
# 225.0    32
# Name: count, dtype: int64
# ['181908.cif', '52458.cif', '164096.cif', '246446.cif', '155554.cif'] [139.0, 225.0, 225.0, 139.0, 139.0] ['Other', 'Other', 'Other', 'Other', 'Fluorite/Rutile']
# Saved result to sg_icsd_pair_139-225.json
# ****************************************
#
# prototype
# Rocksalt/Zincblende/CsCl    8
# Ternary                     7
# Other                       6
# Binary                      6
# Fluorite/Rutile             6
# Perovskite                  3
# Quaternary                  1
# Name: count, dtype: int64 sg_number
# 62.0    37
# Name: count, dtype: int64
# ['166445.cif', '182269.cif', '31543.cif', '55137.cif', '162876.cif'] [62.0, 62.0, 62.0, 62.0, 62.0] ['Rocksalt/Zincblende/CsCl', 'Other', 'Other', 'Binary', 'Rocksalt/Zincblende/CsCl']
# prototype
# Rocksalt/Zincblende/CsCl    19
# Fluorite/Rutile             18
# Ternary                     17
# Other                       13
# Binary                       7
# Perovskite                   6
# Quaternary                   2
# Spinel                       1
# Name: count, dtype: int64 sg_number
# 194.0    46
# 62.0     37
# Name: count, dtype: int64
# ['166442.cif', '166445.cif', '182269.cif', '27422.cif', '28339.cif'] [194.0, 62.0, 62.0, 194.0, 194.0] ['Rocksalt/Zincblende/CsCl', 'Rocksalt/Zincblende/CsCl', 'Other', 'Other', 'Other']
# Saved result to sg_icsd_pair_62-194.json
# ****************************************
